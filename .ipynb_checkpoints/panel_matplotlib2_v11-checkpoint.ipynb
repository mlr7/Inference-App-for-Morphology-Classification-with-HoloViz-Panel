# %% [markdown]
# # Inference App for Morphology Classification

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

import pandas as pd; 
import numpy as np; 

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import seaborn as sns

import panel as pn
pn.extension() # to viz dashboard in jupyter nb
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ### Data ingest

# %%
df = pd.read_csv('./data_in/occupancy.csv')

print(df.shape)
display(df.head(2))
# Out:
# (8143, 7)
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 1  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
#
#    Occupancy
# 0          1
# 1          1

# %% [markdown]
# ### Visualization and utility fxn definitions

# %%
#def viz4(mu=mu):
#def viz4(mean=mu):

def viz4(mean=10):
    plt.figure(figsize=(3,3))
    g_data = np.random.normal(mean, 1, 1000)
    ax = sns.histplot(g_data)
    plt.close()
    return ax.figure

# %%
# https://matplotlib.org/stable/tutorials/introductory/images.html

img = mpimg.imread('./data_pics1/Picture1.png')
imgplot = plt.imshow(img)

# %%
#def viz6(path_pic, pic_num):
def viz6(pic_num):
    #img = mpimg.imread('./data_pics1/Picture1.png')
    #img = mpimg.imread('./data_pics1/0_Smooth-Completely-round_0.jpg')
    img = mpimg.imread('./data_pics1/1_Disk, Face-on, Loose Spiral_1.jpg')
    #img = mpimg.imread(path_pic)
    ax = plt.imshow(img)
    plt.close()
    return ax.figure

# %%
#viz6('./data_pics1/Picture1.png', 3)
viz6(3)

# %%
def viz5(pts=10):
    plt.figure(figsize=(3,3))
    g_data = np.random.normal(100, 25, pts)
    ax = sns.histplot(g_data)
    plt.close()
    return ax.figure

# %%
#find_outliers(variable='Temperature', window=20, sigma=10)
#viz3(data)
#viz4(200)
viz5(20000)

# %%
def button_action1():
    pass

# %% [markdown]
# ### App Creation

# %%
#import panel as pn
#pn.extension()

#window = pn.widgets.IntSlider(name='window', value=30, start=1, end=60)
#sigma = pn.widgets.IntSlider(name='sigma', value=10, start=0, end=20)

#interactive = pn.bind(find_outliers, window=window, sigma=sigma)
#interactive = pn.bind(viz3, window=window, sigma=sigma)


#mu = pn.widgets.IntSlider(name='mu', value=10, start=0, end=20)
#interactive = pn.bind(viz4, mean=mu)

#mu = pn.widgets.IntSlider(name='mu', value=100, start=0, end=20)
#interactive = pn.bind(viz4, mean=mu)

#points = pn.widgets.IntSlider(name='points', value=100, start=0, end=1000)
#interactive = pn.bind(viz5, pts=points)

#pics = pn.widgets.IntSlider(name='pics', value=0, start=0, end=5)
#interactive = pn.bind(viz6, pic_num=pics)

pics = pn.widgets.Button(name='Action_1')
pics.on_click(button_action1)


interactive = pn.bind(viz6, pic_num=pics)

# %%
#select1 = pn.widgets.Select(options=list("option_1", "option_2"), name="select_1")

#select1 = pn.widgets.Select(options=["option1", "option2"], name="select_1")
select1 = pn.widgets.Select(options=["option1", "option2"])

# %%
#first_app = pn.Column(window, sigma, interactive)
#first_app = pn.Column(interactive)
#first_app = pn.Column(data, viz3)

#first_app = pn.Column(viz4)

#first_app = pn.Column(mu, viz4)

#first_app = pn.Column(mu, interactive)
#first_app = pn.Row(mu, interactive)

#first_app = pn.Column(points, interactive)

#first_app = pn.Column(pics, interactive)

#first_app = pn.Column(pn.Row(pics, interactive))
#first_app = pn.Column(pic_num, viz6)

first_app = pn.Column(pn.Row(select1, pics, pics, align="center"), pn.Row(interactive, interactive, align="center"))
first_app
# Out:
# Column
#     [0] Row(align='center')
#         [0] Select(options=['option1', 'option2'], value='option1')
#         [1] Button(name='Action_1')
#         [2] Button(name='Action_1')
#     [1] Row(align='center')
#         [0] ParamFunction(function)
#         [1] ParamFunction(function)

# %% [markdown]
# ### Launch App Externally

# %%
first_app.show()

# %% [markdown]
# ### References

# %%
# https://panel.holoviz.org/getting_started/index.html
# https://panel.holoviz.org/getting_started/build_app.html

# https://foxnic.github.io/simple_dashboard.html # sns hist ex
